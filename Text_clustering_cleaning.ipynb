# %%
#importing Libraries required

import nltk, re, pprint
from nltk import word_tokenize
from urllib import request
from nltk import sent_tokenize
from nltk.corpus import stopwords
import numpy as np
from nltk.corpus import gutenberg
from nltk.corpus import stopwords
from nltk.tokenize.treebank import TreebankWordDetokenizer
from nltk.stem.porter import PorterStemmer
from nltk.collocations import *

# %%
#Importing 1st book 

emma = gutenberg.raw('whitman-leaves.txt')
books=[]
doc=[]
books1=[]
senta=[]
books1_stemmed=[]
stopli=set(stopwords.words('english')) #setting Stopwords
porter=PorterStemmer()                 #setting instance for stemming
a=word_tokenize(emma)                  #tokenizing the text
senta=[w.lower() for w in a]           #lowering the case of text
books=[w for w in senta if not w in stopli] #removing the stopwords
books1=[w for w in books if w.isalpha()]    #removing the punctuations
books1_stemmed=[porter.stem(w) for w in books1] #stemming the words
b=TreebankWordDetokenizer().detokenize(books1_stemmed) #detokenizing the books
doc=[w for w in books1_stemmed]

x1=[]
for i in range (0,200*150,150):
     x1.append(doc[i:i+150])
z=[0]*200

# %%
import matplotlib.pyplot as plt
fs=nltk.FreqDist(books1_stemmed)              # Mapping Frequency Distrubution
fs.plot(30,cumulative=False)       # Plotting Graph
plt.show()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(books1_stemmed)
scored = finder.score_ngrams(bigram_measures.raw_freq)
sorted(finder.nbest(bigram_measures.raw_freq, 10))
# Out:
# [('day', 'night'),
#  ('everi', 'one'),
#  ('long', 'long'),
#  ('man', 'woman'),
#  ('men', 'women'),
#  ('old', 'age'),
#  ('pioneer', 'pioneer'),
#  ('sing', 'song'),
#  ('young', 'man'),
#  ('young', 'men')]

# %%
#Importing 2nd book

book2 = gutenberg.raw('melville-moby_dick.txt')
books1=[]
doc1=[]
books11=[]
senta1=[]
books1_stemmed1=[]
stopli1=set(stopwords.words('english')) #setting Stopwords
porter1=PorterStemmer()                 #setting instance for stemming
a1=word_tokenize(book2)                 #tokenizing the text
senta1=[w.lower() for w in a1]          #lowering the case of text
books1=[w for w in senta1 if not w in stopli1] #removing the stopwords
books11=[w for w in books1 if w.isalpha()]     #removing the punctuations
books1_stemmed1=[porter.stem(w) for w in books11] #stemming the words
b1=TreebankWordDetokenizer().detokenize(books1_stemmed1) #detokenizing the books
doc1=[w for w in books1_stemmed1]

x2=[]
for i in range (0,200*150,150):
     x2.append(doc1[i:i+150])
b=[1]*200

# %%
import matplotlib.pyplot as plt
fs=nltk.FreqDist(books1_stemmed1)              # Mapping Frequency Distrubution
fs.plot(30,cumulative=False)       # Plotting Graph
plt.show()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(books1_stemmed1)
scored = finder.score_ngrams(bigram_measures.raw_freq)
sorted(finder.nbest(bigram_measures.raw_freq, 10))
# Out:
# [('aye', 'aye'),
#  ('captain', 'ahab'),
#  ('captain', 'peleg'),
#  ('cri', 'ahab'),
#  ('mobi', 'dick'),
#  ('old', 'man'),
#  ('one', 'hand'),
#  ('right', 'whale'),
#  ('sperm', 'whale'),
#  ('white', 'whale')]

# %%
#Importing 3rd book

book3 = gutenberg.raw('bible-kjv.txt')
books2=[]
doc2=[]
books12=[]
senta2=[]
books1_stemmed2=[]
stopli2=set(stopwords.words('english')) #setting Stopwords
porter2=PorterStemmer()                 #setting instance for stemming
a2=word_tokenize(book3)  #tokenizing the text
senta2=[w.lower() for w in a2]       #lowering the case of text
books2=[w for w in senta2 if not w in stopli2] #removing the stopwords
books12=[w for w in books2 if w.isalpha()] #removing the punctuations
books1_stemmed2=[porter.stem(w) for w in books12] #stemming the words
b2=TreebankWordDetokenizer().detokenize(books1_stemmed2) #detokenizing the books
doc2=[w for w in books1_stemmed2]

x3=[]
for i in range (0,200*150,150):
    x3.append(doc2[i:i+150])
c=[2]*200

# %%
import matplotlib.pyplot as plt
fs=nltk.FreqDist(books1_stemmed2)              # Mapping Frequency Distrubution
fs.plot(30,cumulative=False)       # Plotting Graph
plt.show()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(books1_stemmed2)
scored = finder.score_ngrams(bigram_measures.raw_freq)
sorted(finder.nbest(bigram_measures.raw_freq, 10))
# Out:
# [('came', 'pass'),
#  ('children', 'israel'),
#  ('lord', 'god'),
#  ('said', 'unto'),
#  ('saith', 'lord'),
#  ('thou', 'hast'),
#  ('thou', 'shalt'),
#  ('unto', 'lord'),
#  ('unto', 'thee'),
#  ('ye', 'shall')]

# %%
#Importing 4th book

book4 = gutenberg.raw('austen-emma.txt')
books3=[]
doc3=[]
books13=[]
senta3=[]
books1_stemmed3=[]
stopli3=set(stopwords.words('english')) #setting Stopwords
porter3=PorterStemmer()                 #setting instance for stemming
a3=word_tokenize(book4)  #tokenizing the text
senta3=[w.lower() for w in a3]       #lowering the case of text
books3=[w for w in senta3 if not w in stopli3] #removing the stopwords
books13=[w for w in books3 if w.isalpha()] #removing the punctuations
books1_stemmed3=[porter.stem(w) for w in books13] #stemming the words
b3=TreebankWordDetokenizer().detokenize(books1_stemmed3) #detokenizing the books
doc3=[w for w in books1_stemmed3]

x4=[]
for i in range (0,200*150,150):
       x4.append(doc3[i:i+150])
d=[3]*200

# %%
import matplotlib.pyplot as plt
fs=nltk.FreqDist(books1_stemmed3)              # Mapping Frequency Distrubution
fs.plot(30,cumulative=False)       # Plotting Graph
plt.show()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(books1_stemmed3)
scored = finder.score_ngrams(bigram_measures.raw_freq)
sorted(finder.nbest(bigram_measures.raw_freq, 10))
# Out:
# [('everi', 'bodi'),
#  ('everi', 'thing'),
#  ('frank', 'churchil'),
#  ('great', 'deal'),
#  ('jane', 'fairfax'),
#  ('miss', 'bate'),
#  ('miss', 'fairfax'),
#  ('miss', 'woodhous'),
#  ('said', 'emma'),
#  ('young', 'man')]

# %%
#Importing 5th book

book5 = gutenberg.raw('blake-poems.txt')
books4=[]
doc4=[]
books14=[]
senta4=[]
books1_stemmed4=[]
stopli4=set(stopwords.words('english')) #setting Stopwords
porter4=PorterStemmer()                 #setting instance for stemming
a4=word_tokenize(book5)  #tokenizing the text
senta4=[w.lower() for w in a4]       #lowering the case of text
books4=[w for w in senta4 if not w in stopli4] #removing the stopwords
books14=[w for w in books4 if w.isalpha()] #removing the punctuations
books1_stemmed4=[porter.stem(w) for w in books14] #stemming the words
b4=TreebankWordDetokenizer().detokenize(books1_stemmed4) #detokenizing the books
doc4=[w for w in books1_stemmed4]
x5=[]
for i in range (0,200*150,150):
    x5.append(doc4[i:i+150])
e=[4]*200

# %%
import matplotlib.pyplot as plt
fs=nltk.FreqDist(books1_stemmed4)              # Mapping Frequency Distrubution
fs.plot(30,cumulative=False)       # Plotting Graph
plt.show()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(books1_stemmed4)
scored = finder.score_ngrams(bigram_measures.raw_freq)
sorted(finder.nbest(bigram_measures.raw_freq, 10))
# Out:
# [('day', 'night'),
#  ('fade', 'away'),
#  ('hear', 'voic'),
#  ('human', 'form'),
#  ('like', 'thee'),
#  ('littl', 'boy'),
#  ('littl', 'girl'),
#  ('littl', 'lamb'),
#  ('merci', 'piti'),
#  ('weep', 'weep')]

# %%
#Importing 6th book

book6 = gutenberg.raw('shakespeare-hamlet.txt')
books5=[]
doc5=[]
books15=[]
senta5=[]
books1_stemmed5=[]
stopli5=set(stopwords.words('english')) #setting Stopwords
porter5=PorterStemmer()                 #setting instance for stemming
a5=word_tokenize(book6)  #tokenizing the text
senta5=[w.lower() for w in a5]       #lowering the case of text
books5=[w for w in senta5 if not w in stopli5] #removing the stopwords
books15=[w for w in books5 if w.isalpha()] #removing the punctuations
books1_stemmed5=[porter.stem(w) for w in books15] #stemming the words
b5=TreebankWordDetokenizer().detokenize(books1_stemmed5) #detokenizing the books
doc5=[w for w in books1_stemmed5]

x6=[]
for i in range (0,200*150,150):
     x6.append(doc5[i:i+150])
f=[5]*200

# %%
import matplotlib.pyplot as plt
fs=nltk.FreqDist(books1_stemmed5)              # Mapping Frequency Distrubution
fs.plot(30,cumulative=False)       # Plotting Graph
plt.show()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(books1_stemmed5)
scored = finder.score_ngrams(bigram_measures.raw_freq)
sorted(finder.nbest(bigram_measures.raw_freq, 10))
# Out:
# [('enter', 'hamlet'),
#  ('enter', 'king'),
#  ('exeunt', 'enter'),
#  ('good', 'lord'),
#  ('hamlet', 'ham'),
#  ('haue', 'seen'),
#  ('hor', 'lord'),
#  ('lord', 'ham'),
#  ('lord', 'hamlet'),
#  ('wee', 'l')]

# %%
#Importing 7th book

book7 = gutenberg.raw('austen-persuasion.txt')
books6=[]
doc6=[]
books16=[]
senta6=[]
books1_stemmed6=[]
stopli6=set(stopwords.words('english')) #setting Stopwords
porter6=PorterStemmer()                 #setting instance for stemming
a6=word_tokenize(book7)  #tokenizing the text
senta6=[w.lower() for w in a6]       #lowering the case of text
books6=[w for w in senta6 if not w in stopli6] #removing the stopwords
books16=[w for w in books6 if w.isalpha()] #removing the punctuations
books1_stemmed6=[porter.stem(w) for w in books16] #stemming the words
b6=TreebankWordDetokenizer().detokenize(books1_stemmed6) #detokenizing the 
doc6=[w for w in books1_stemmed6]
x7=[]
for i in range (0,200*150,150):
     x7.append(doc6[i:i+150])
g=[6]*200

# %%
import matplotlib.pyplot as plt
fs=nltk.FreqDist(books1_stemmed6)              # Mapping Frequency Distrubution
fs.plot(30,cumulative=False)       # Plotting Graph
plt.show()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(books1_stemmed6)
scored = finder.score_ngrams(bigram_measures.raw_freq)
sorted(finder.nbest(bigram_measures.raw_freq, 10))
# Out:
# [('captain', 'benwick'),
#  ('captain', 'wentworth'),
#  ('ladi', 'russel'),
#  ('miss', 'elliot'),
#  ('mr', 'clay'),
#  ('mr', 'croft'),
#  ('mr', 'elliot'),
#  ('mr', 'musgrov'),
#  ('mr', 'smith'),
#  ('sir', 'walter')]
